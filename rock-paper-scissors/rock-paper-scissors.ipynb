# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

options = ["stone", "paper", "scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

max_games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

import math
games_to_win = math.ceil(max_games/2)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def computer_game():
    return (random.choice(options))

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def play():

    while True:
        testgame = input("What's your choice? 'stone', 'paper' or 'scissors' ")

        if(testgame in options):
            break
        else:
            print ("You have to choice one of them: 'stone', 'paper' or 'scissors'.")
            
    return testgame

            
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def resolve(human, machine):
    if(human==machine):
        return 0
    elif(human == "stone"):
        if(machine == "scissors"):
            return 2
        elif(machine == "paper"):
            return 1
    elif(human == "paper"):
        if(machine == "scissors"):
            return 1
        elif(machine == "stone"):
            return 2
    else:
        if(machine == "paper"):
            return 2
        elif(machine == "stone"):
            return 1
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game(score_human, score_machine):
    user = play()
    machine = computer_game()
    
    print("Your choice is %s and machine choice is %s" % (user, machine))
    
    resolved = resolve(user, machine)
    if(resolved == 1):
        score_machine += 1
        print("Machine wins. SCORES: Human: %x - Machine: %x \n" % (score_human, score_machine))
    elif(resolved == 2):
        score_human += 1
        print("You win. SCORES: Human: %x - Machine: %x \n" % (score_human, score_machine))
    else:
        print("Tie\n")
    
    return (score_human, score_machine)
    
# Create two variables that accumulate the wins of each participant

score_human = 0
score_machine = 0
games = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

print ("Let's play the famous 'Rock, Paper, Scissors' against your computer. The winner is the best of %x " % (max_games))

while (score_human < games_to_win) and (score_machine < games_to_win) and (games < max_games):

    score_human, score_machine = game(score_human, score_machine)
    games += 1
    
# Print by console the winner of the game based on who has more accumulated wins
if (score_human > score_machine):
    print ("And the WINNER is... YOU!")
elif(score_human < score_machine):
    print ("And the WINNER is... THE MACHINE!")
else:
    print("There is a tie!")
# Out:
# Let's play the famous 'Rock, Paper, Scissors' against your computer. The winner is the best of 5
# What's your choice? 'stone', 'paper' or 'scissors' stone
# Your choice is stone and machine choice is scissors
# You win. SCORES: Human: 1 - Machine: 0
#
# What's your choice? 'stone', 'paper' or 'scissors' stone
# Your choice is stone and machine choice is paper
# Machine wins. SCORES: Human: 1 - Machine: 1
#
# What's your choice? 'stone', 'paper' or 'scissors' stone
# Your choice is stone and machine choice is scissors
# You win. SCORES: Human: 2 - Machine: 1
#
# What's your choice? 'stone', 'paper' or 'scissors' stone
# Your choice is stone and machine choice is paper
# Machine wins. SCORES: Human: 2 - Machine: 2
#
# What's your choice? 'stone', 'paper' or 'scissors' stone
# Your choice is stone and machine choice is paper
# Machine wins. SCORES: Human: 2 - Machine: 3
#
# And the WINNER is... THE MACHINE!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def number_games():

    while True:
        maxgames = input("Choose the maximum number of games: ")
        
        try:
            val = int(maxgames)
            break
        except ValueError:
            print ("You have to introduce an entire number")
            
    return int(maxgames)

# Assign a list of 5 possible options.

options = ["stone", "paper", "scissors", "lizard", "spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used

print ("Let's play the 'not so famous' 'Rock, Paper, Scissors, Lizard, Spock' against your computer.")

max_games = number_games()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

import math

games_to_win = math.ceil(max_games/2)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def computer_game():
    return (random.choice(options))

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def play():

    while True:
        testgame = input("What's your choice? 'stone', 'paper', 'scissors', 'lizard' or 'spock' ")

        if(testgame in options):
            break
        else:
            print ("You have to choice one of them: 'stone', 'paper', 'scissors', 'lizard' or 'spock'.")
            
    return testgame

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options

def resolve(human, machine):
    if(human==machine):
        return 0
    elif(human == "stone"):
        if(machine == "scissors") or (machine == "lizard"):
            return 2
        elif(machine == "paper") or (machine == "spock"):
            return 1
    elif(human == "paper"):
        if(machine == "stone") or (machine == "spock"):
            return 2
        elif(machine == "scissors") or (machine == "lizard"):
            return 1
    elif(human == "scissors"):
        if(machine == "paper") or (machine == "lizard"):
            return 2
        elif(machine == "stone") or (machine == "spock"):
            return 1
    elif(human == "lizard"):
        if(machine == "paper") or (machine == "spock"):
            return 2
        elif(machine == "stone") or (machine == "lizard"):
            return 1
    else:
        if(machine == "stone") or (machine == "scissors"):
            return 2
        elif(machine == "paper") or (machine == "lizard"):
            return 1
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game(score_human, score_machine):
    user = play()
    machine = computer_game()
    
    print("Your choice is %s and machine choice is %s" % (user, machine))
    
    resolved = resolve(user, machine)
    if(resolved == 1):
        score_machine += 1
        print("Machine wins. SCORES: Human: %x - Machine: %x \n" % (score_human, score_machine))
    elif(resolved == 2):
        score_human += 1
        print("You win. SCORES: Human: %x - Machine: %x \n" % (score_human, score_machine))
    else:
        print("Tie\n")
    
    return (score_human, score_machine)
    
# Create two variables that accumulate the wins of each participant

score_human = 0
score_machine = 0
games = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while (score_human < games_to_win) and (score_machine < games_to_win) and (games < max_games):

    score_human, score_machine = game(score_human, score_machine)
    games += 1
    
# Print by console the winner of the game based on who has more accumulated wins
if (score_human > score_machine):
    print ("And the WINNER is... YOU!")
elif(score_human < score_machine):
    print ("And the WINNER is... THE MACHINE!")
else:
    print("There is a tie!")
# Out:
# Let's play the 'not so famous' 'Rock, Paper, Scissors, Lizard, Spock' against your computer.
# Choose the maximum number of games: 5
# What's your choice? 'stone', 'paper', 'scissors', 'lizard' or 'spock' lizard
# Your choice is lizard and machine choice is spock
# You win. SCORES: Human: 1 - Machine: 0
#
# What's your choice? 'stone', 'paper', 'scissors', 'lizard' or 'spock' lizard
# Your choice is lizard and machine choice is paper
# You win. SCORES: Human: 2 - Machine: 0
#
# What's your choice? 'stone', 'paper', 'scissors', 'lizard' or 'spock' lizard
# Your choice is lizard and machine choice is stone
# Machine wins. SCORES: Human: 2 - Machine: 1
#
# What's your choice? 'stone', 'paper', 'scissors', 'lizard' or 'spock' lizard
# Your choice is lizard and machine choice is paper
# You win. SCORES: Human: 3 - Machine: 1
#
# And the WINNER is... YOU!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
